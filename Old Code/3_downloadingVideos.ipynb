# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
import json
import requests

file_path = "/content/drive/MyDrive/greWords/greWords.json"

with open(file_path, "r") as file:
    data = json.load(file)

print(data)

outputDirectory = "/content/drive/MyDrive/greWords/downloadedVideos/"
os.makedirs(outputDirectory, exist_ok=True)

# Iterate through each word in the data
for currentWord, wordData in data.items():
    # Iterate through each clipData for the word
    for clip_index, clip_info in wordData["clipData"].items():
        video_url = clip_info["videoURL"]
        video_info = clip_info["videoInfo"]

        os.makedirs(outputDirectory+"/"+currentWord, exist_ok=True)

        # Generate a file name based on word, clip index, and video info
        file_name = f"{currentWord}_clip{clip_index}_{video_info.replace(' ', '_')}.mp4"
        file_path = os.path.join(outputDirectory, currentWord +"/"+ clip_index + ".mp4")

        # Download the video
        response = requests.get(video_url, stream=True)
        with open(file_path, "wb") as video_file:
            for chunk in response.iter_content(chunk_size=1024 * 1024):
                if chunk:
                    video_file.write(chunk)

        print(f"Downloaded video: {file_name}")
# Out:
# {'brother': {'meaning': 'Degrade or humble; to lower in rank, status, or esteem', 'wordIndex': 1, 'wordUsed': False, 'clipsFound': 4, 'clipData': {'1': {'videoURL': 'https://www.playphrase.me/video/5b96b007cc77853d88561aa4/628ea5c3b071e7f3ed0c0162.mp4', 'subtitle': "You know where the fuck I'm from. This Bompton, brother.", 'videoInfo': 'Straight Outta Compton (2015) [01:48:35]'}, '2': {'videoURL': 'https://www.playphrase.me/video/5b96b007cc77853d88561aa4/628ea5c3b071e7f3ed0c00db.mp4', 'subtitle': 'What that Ruthless like, brother?', 'videoInfo': 'Straight Outta Compton (2015) [01:38:43]'}, '3': {'videoURL': 'https://www.playphrase.me/video/5b96b007cc77853d88561aa4/628ea5c2b071e7f3ed0bfcdb.mp4', 'subtitle': "Keep talkin' that bullshit on your way out the door, brother.", 'videoInfo': 'Straight Outta Compton (2015) [00:27:48]'}, '4': {'videoURL': 'https://www.playphrase.me/video/5b1832a08079eb4cd4a4a413/6276d4772827a11674be8cf4.mp4', 'subtitle': 'Hit the lights, brother.', 'videoInfo': 'Boyz n the Hood (1991) [01:38:51]'}}, 'searched': True}, 'abate': {'meaning': 'Reduce, diminish', 'wordIndex': 2, 'wordUsed': False, 'clipsFound': 4, 'clipData': {'1': {'videoURL': 'https://www.playphrase.me/video/5b1838758079eb4cd4a55413/628408f9c3731da7ee2fdb80.mp4', 'subtitle': 'There lives within the very flame of love... a kind of wick or snuff that will abate it.', 'videoInfo': 'Hamlet (1996) [03:00:25]'}, '2': {'videoURL': 'https://www.playphrase.me/video/5b1839dc8079eb4cd4a57f59/629c44b514bb6d3b4fc38840.mp4', 'subtitle': 'Consumes it with a burning flame that does not abate.', 'videoInfo': 'Born of Hope (2009) [00:23:20]'}, '3': {'videoURL': 'https://www.playphrase.me/video/5b96ab52cc77853d885611ef/628b9403b071e717a65fbf21.mp4', 'subtitle': 'You basically want to try to either aggravate the demon or abate it.', 'videoInfo': 'Demon House (2018) [00:20:45]'}, '4': {'videoURL': 'https://www.playphrase.me/video/5b183b3d8079eb4cd4a5a9b8/627826d4b05db515a22da6b1.mp4', 'subtitle': 'l have unleashed a raging shit storm of epic proportions on the board of trustees of that pissant school that will not abate until those girls seek enrollment elsewhere.', 'videoInfo': 'Remember Me (2010) [01:33:10]'}}, 'searched': True}, 'abdicate': {'meaning': 'Formally give up the throne (or some other power or responsibility)', 'wordIndex': 3, 'wordUsed': False, 'clipsFound': 0, 'clipData': {}, 'searched': False}, 'aberrant': {'meaning': 'Abnormal, deviant', 'wordIndex': 4, 'wordUsed': False, 'clipsFound': 0, 'clipData': {}, 'searched': False}, 'abeyance': {'meaning': 'Temporary suspension, inactivity', 'wordIndex': 5, 'wordUsed': False, 'clipsFound': 0, 'clipData': {}, 'searched': False}, 'abhor': {'meaning': 'Detest, regard with disgust', 'wordIndex': 6, 'wordUsed': False, 'clipsFound': 0, 'clipData': {}, 'searched': False}, 'abjure': {'meaning': 'Give up, renounce; repudiate, recant, or shun (especially formally or under oath)', 'wordIndex': 7, 'wordUsed': False, 'clipsFound': 0, 'clipData': {}, 'searched': False}, 'abrasive': {'meaning': 'Rough, suitable for grinding or polishing (such as sandpaper); causing irritation or annoyance', 'wordIndex': 8, 'wordUsed': False, 'clipsFound': 0, 'clipData': {}, 'searched': False}, 'abreast': {'meaning': 'Side-by-side. The more common "abreast of" means keeping up with, staying aware of, or remaining equal in progress with.', 'wordIndex': 9, 'wordUsed': False, 'clipsFound': 0, 'clipData': {}, 'searched': False}, 'abridge': {'meaning': 'Reduce or lessen; shorten by omitting parts throughout while retaining the main idea', 'wordIndex': 10, 'wordUsed': False, 'clipsFound': 0, 'clipData': {}, 'searched': False}, 'abscission': {'meaning': 'Cutting off; sudden termination; the separation of leaves, petals, or other parts from a plant or animal', 'wordIndex': 11, 'wordUsed': False, 'clipsFound': 0, 'clipData': {}, 'searched': False}, 'abscond': {'meaning': 'Depart suddenly and secretively', 'wordIndex': 12, 'wordUsed': False, ' ...
# Downloaded video: brother_clip1_Straight_Outta_Compton_(2015)_[01:48:35].mp4
# Downloaded video: brother_clip2_Straight_Outta_Compton_(2015)_[01:38:43].mp4
# Downloaded video: brother_clip3_Straight_Outta_Compton_(2015)_[00:27:48].mp4
# Downloaded video: brother_clip4_Boyz_n_the_Hood_(1991)_[01:38:51].mp4
# Downloaded video: abate_clip1_Hamlet_(1996)_[03:00:25].mp4
# Downloaded video: abate_clip2_Born_of_Hope_(2009)_[00:23:20].mp4
# Downloaded video: abate_clip3_Demon_House_(2018)_[00:20:45].mp4
# Downloaded video: abate_clip4_Remember_Me_(2010)_[01:33:10].mp4
